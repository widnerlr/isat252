# %% [markdown]
# # my first notebook

# %%
print('my first notebook')
# Out:
# my first notebook

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
print(a)
# Out:
# 1

# %% [markdown]
# print the variable a.
#
# >the **value** of a is 1.
#
# 1. a is 1
# 2. b is 2
# 3. c is 4
#
# [JMU] (http://www.jmu.edu)
# ![image.png](attachment:image.png) ![image]

# %%
c =4

# %%
print(c)
# Out:
# 4

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C)
plt.plot(X, S)

plt.show()

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.14.3)
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import numpy

# %%
print(numpy)
# Out:
# <module 'numpy' from '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/__init__.py'>

# %% [markdown]
# # James Madison University
# **Lillian Widner**
#
# *B.B.A. Finance*
# >Expected Graduation May 2022
